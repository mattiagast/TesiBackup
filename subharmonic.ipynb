# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Definizione dell'equazione di Van der Pol forzata
# def vanderpol(y, t, mu, A, omega):
#     x, v = y
#     dxdt = v
#     dvdt = mu * (1 - x**2) * v - x + A * np.cos(omega * t)
#     return [dxdt, dvdt]

def vanderpol(y, t, mu, A):
    x, v = y
    # La frequenza aumenta linearmente con il tempo
    omega_t = 0.05 * t 
    # Usiamo l'integrale della frequenza per la fase
    dxdt = v
    # dvdt = mu * (1 - x**2) * v - x + A * np.cos(0.2 * t * t)
    # dvdt = mu * (1 - x**2) * v - x + A * np.cos(0.1 * 0.05 * t * t) # bello
    dvdt = mu * (1 - x**2) * v - x + A * np.cos(0.2 * t * t) # bello
    # dvdt = mu * (1 - x**2) * v - x + 30 * np.cos(0.3 * t * t) # bello
    return [dxdt, dvdt]

# Parametri suggeriti per la coesistenza di attrattori
mu = 5.0
A = 12.0
# omega = 2.46

# Tempo di simulazione (abbastanza lungo per superare il transitorio)
# t = np.linspace(0, 50, 5000)
# t = np.linspace(0, 100, 10000)
# t = np.linspace(0, 200, 20000)
t = np.linspace(0, 300, 30000)
# t = np.linspace(0, 400, 40000)


# Caso 1: Condizione iniziale "vicina al centro"
y0_1 = [0.1, 0.0]
sol1 = odeint(vanderpol, y0_1, t, args=(mu, A))

# Caso 2: Condizione iniziale "lontana"
y0_2 = [4.0, 0.0]
sol2 = odeint(vanderpol, y0_2, t, args=(mu, A))

# Caso 3: Una condizione iniziale intermedia
y0_3 = [0.1, -2.0]
sol3 = odeint(vanderpol, y0_3, t, args=(mu, A))

# ============================
# Visualizzazione dei risultati
# ============================

plt.figure(figsize=(12, 10))

# --- 1) Grafico Temporale (regime stazionario) ---
plt.subplot(2, 2, 1)
plt.plot(t[-5000:], sol1[-5000:, 0], label='Partenza x=0.1', color='blue')
plt.plot(t[-5000:], sol2[-5000:, 0], label='Partenza x=4.0', color='red', alpha=0.8)
plt.plot(t[-5000:], sol3[-5000:, 0], label='Partenza x=2.0', color='green', alpha=0.8)
plt.title("Risposta Temporale dopo 150")
plt.xlabel("Tempo")
plt.ylabel("Posizione x")
plt.legend()

# --- 2) Ritratto di fase ---
plt.subplot(2, 2, 2)
plt.plot(sol1[-5000:, 0], sol1[-5000:, 1], color='blue', label='Attrattore A')
plt.plot(sol2[-5000:, 0], sol2[-5000:, 1], color='red', label='Attrattore B')
plt.plot(sol3[-5000:, 0], sol3[-5000:, 1], color='green', label='Attrattore C')
plt.title("Ritratto di fase")
plt.xlabel("x")
plt.ylabel("v")
plt.legend()

# --- 3) Evoluzione completa nel tempo ---
plt.subplot(2, 1, 2)
plt.plot(t, sol1[:, 0], color='blue', label='x(0)=0.1', alpha=0.8)
plt.plot(t, sol2[:, 0], color='red', label='x(0)=4.0', alpha=0.8)
plt.plot(t, sol3[:, 0], color='green', label='x(0)=0.1, -2', alpha=0.8)
plt.title("Evoluzione completa nel tempo")
plt.xlabel("Tempo")
plt.ylabel("Posizione x")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Conta quanti picchi ci sono negli ultimi 100 secondi
from scipy.signal import find_peaks

peaks1, _ = find_peaks(sol1[-10000:, 0])
peaks2, _ = find_peaks(sol2[-10000:, 0])

print(f"Numero di picchi Caso A: {len(peaks1)}")
print(f"Numero di picchi Caso B: {len(peaks2)}")
# Out:
# Numero di picchi Caso A: 8
# Numero di picchi Caso B: 8

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

def vanderpol(y, t, mu, A, omega):
    x, v = y
    return [v, mu * (1 - x**2) * v - x + A * np.cos(omega * t)]

# Parametri fissi
mu, A, omega = 5.0, 1.2, 2.46
t = np.linspace(0, 50, 500) # Simulazione breve per ogni punto

# Creazione della griglia di condizioni iniziali
x_range = np.linspace(-4, 4, 50)
v_range = np.linspace(-4, 4, 50)
X, V = np.meshgrid(x_range, v_range)

# Riferimento: eseguiamo una simulazione lunga per trovare la fase "Blu" a t=50
ref_sol = odeint(vanderpol, [0.1, 0.0], np.linspace(0, 50, 500), args=(mu, A, omega))
ref_final_x = ref_sol[-1, 0]

basin = np.zeros(X.shape)

print("Calcolo in corso... potrebbe richiedere un minuto.")
for i in range(len(x_range)):
    for j in range(len(v_range)):
        sol = odeint(vanderpol, [X[i,j], V[i,j]], t, args=(mu, A, omega))
        # Se la posizione finale è vicina a quella di riferimento, è Attrattore A
        if np.abs(sol[-1, 0] - ref_final_x) < 0.5:
            basin[i,j] = 1 # Blu
        else:
            basin[i,j] = 2 # Rosso

plt.figure(figsize=(8, 7))
plt.pcolormesh(X, V, basin, cmap='coolwarm', shading='auto')
plt.colorbar(ticks=[1, 2], label='Attrattore').set_ticklabels(['Blu (A)', 'Rosso (B)'])
plt.title(f"Bacini di Attrazione (mu={mu}, omega={omega})")
plt.xlabel("Posizione iniziale (x0)")
plt.ylabel("Velocità iniziale (v0)")
plt.show()
# Out:
# Calcolo in corso... potrebbe richiedere un minuto.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def vanderpol_fixed(y, t, mu, A, omega):
    x, v = y
    return [v, mu * (1 - x**2) * v - x + A * np.cos(omega * t)]

# Parametri per evidenziare le subarmoniche
mu = 5
A = 5
omega = 6  # Forza esterna molto veloce

# t = np.linspace(0, 300, 30000)
t = np.linspace(0, 100, 10000)
sol = odeint(vanderpol_fixed, [0.1, 0.0], t, args=(mu, A, omega))

# Estraiamo l'ultimo tratto per l'analisi
t_zoom = t[-2000:]
x_zoom = sol[-2000:, 0]
forzante = A * np.cos(omega * t_zoom)

plt.figure(figsize=(12, 6))

# GRAFICO TEMPORALE: Confronto diretto
plt.subplot(2, 1, 1)
plt.plot(t_zoom, x_zoom, label='Risposta Oscillatore (x)', color='blue', lw=2)
plt.plot(t_zoom, forzante/5, label='Forzante (scalata / 5)', color='orange', alpha=0.5)
plt.title(f"Sincronizzazione Subarmonica (omega={omega})")
plt.ylabel("Ampiezza")
plt.legend()

# RITRATTO DI FASE: Contiamo le "gobbe"
plt.subplot(2, 1, 2)
plt.plot(sol[-5000:, 0], sol[-5000:, 1], color='blue')
plt.title("Ritratto di Fase: Ogni 'increspatura' è un ciclo della forzante")
plt.xlabel("x")
plt.ylabel("v")

plt.tight_layout()
plt.show()

# %%
# Libraries:
import pysindy as ps
import numpy as np
import matplotlib.pyplot as plt
import dill
import sys
import os

from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.linear_model import Lasso

sys.path.append("/home/mattg/D_CODE") # A questo punto è necessario per non doverlo chiamare i file che usano D_CODE.
from D_CODE.run_simulation import run as run_SRT
from D_CODE.run_simulation_vi import run as run_DCODE
from toolbox.auxiliary_functions import set_param_freq

from data import equations
from data import SINDy_data
# Out:
# /home/mattg/miniforge3/envs/SimbSINDy_env/lib/python3.11/site-packages/pysindy/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound

# %% [markdown]
# ### Data Generations

# %%
# Select ODE & settings:
ode_name = 'TVVdpODE' # help="name of the ode", type=str
ode_param = '5.0,5,0.02' # help="parameters of the ode (default: None)", type=str, default=None
freq = 20 # Dovrebbe essere 195 per avere dt = 5.130 * 10−3 come nel paper di riferimento
dt = 1 / freq
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_ratio = 0.0 # help="noise level (default 0)", type=float, default=0.
dim_x = 3 # help="dimentionality of the problem", type=int
dim_k = 0 # help="dimentionality of the parameterizaiton discovery", type=int
ode_param, freq = set_param_freq(ode_param, freq)
ode = equations.get_ode(ode_name, ode_param)
time_vector = np.arange(0, ode.T + dt, dt)

# %%
# generate data:
X_list, dX_list, param_list, feature_names = SINDy_data.SINDy_data(ode_name=ode_name, 
                                                                   ode_param=ode_param,
                                                                   freq=freq,
                                                                   n_sample=n_sample,
                                                                   noise_ratio=noise_ratio,
                                                                   dim_x=dim_x,
                                                                   dim_k=dim_k)
# X_list = SINDy_data.existence_conditions(X_list, ode.init_low, n_variables=dim_x)

# save data:
# file_path = 'saved/data/TVSelkovODE_data.pkl'
# os.makedirs(os.path.dirname(file_path), exist_ok=True)
# with open(file_path, 'wb') as f:
#     dill.dump((X_list, dX_list, param_list, feature_names), f)

# %%
SINDy_data.plot_configuration(np.array(X_list)[:,:,:])
SINDy_data.plot_configuration(np.array(X_list)[:,:,0:1], ode.T)
SINDy_data.plot_configuration(np.array(X_list)[:,:,1:2], ode.T)

# %% [markdown]
# #### Check SINDy

# %%
X_lista = [np.array(x)[:500, :] for x in X_list]
dX_lista = [np.array(dx)[:500, :] for dx in dX_list]

model = ps.SINDy(feature_names=feature_names, feature_library=ps.PolynomialLibrary(degree=3, include_bias=True), optimizer=ps.STLSQ(threshold=0.5))
model.fit(X_lista, t=dt, multiple_trajectories=True, x_dot=dX_lista)
print("Estimated SINDy model: ")
model.print()
# Out:
# Estimated SINDy model:
# (X0)' = 4.072 X0 + -0.629 X1 + -4.085 X0 X1^2
# (X1)' = 0.986 X0
# (X2)' = 1.000 1

# %%
X_lista = [np.array(x)[300:800, :] for x in X_list]
dX_lista = [np.array(dx)[300:800, :] for dx in dX_list]

# lambda function:
building_blocks_lambda = lambda X0, X1, X2: np.cos(0.02*X2**2)
function_names = lambda X0, X1, X2: "cos( 0.02*"+ X2 + "^2 )"

# building the library:
from toolbox.auxiliary_functions import intercept_library_fun
intercept_library = intercept_library_fun(dim_x+dim_k)
polynomial_library = ps.PolynomialLibrary(degree=3, include_bias=False)
custom_library = ps.CustomLibrary(library_functions=[building_blocks_lambda], function_names=[function_names]) # custom library with building block
generalized_library = ps.ConcatLibrary([polynomial_library, custom_library])
final_library = ps.ConcatLibrary([intercept_library, generalized_library]) # add the intercept


model = ps.SINDy(feature_names=feature_names, feature_library=final_library, optimizer=ps.STLSQ(threshold=0.7))
model.fit(X_lista, t=dt, multiple_trajectories=True, x_dot=dX_lista)
print("Estimated SINDy model: ")
model.print()
# Out:
# Estimated SINDy model:
# (X0)' = 3.872 X0 + -0.791 X1 + -4.670 X0 X1^2 + 5.767 cos( 0.02*X2^2 )
# (X1)' = 0.988 X0
# (X2)' = 1.000 1

# %% [markdown]
# #### Check SR

# %%
# Libraries:
import pysindy as ps
import numpy as np
import matplotlib.pyplot as plt
import dill
import sys
import os

from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.linear_model import Lasso

sys.path.append("/home/mattg/D_CODE") # A questo punto è necessario per non doverlo chiamare i file che usano D_CODE.
from D_CODE.run_simulation import run as run_SRT
from D_CODE.run_simulation_vi import run as run_DCODE
from toolbox.auxiliary_functions import set_param_freq

from data import equations
from data import SINDy_data
# Out:
# /home/mattg/miniforge3/envs/SimbSINDy_env/lib/python3.11/site-packages/pysindy/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound

# %%
# Select ODE & settings:
ode_name = 'TVVdpODE' # help="name of the ode", type=str
ode_param = '5.0,5.0,0.2' # help="parameters of the ode (default: None)", type=str, default=None
freq = 20 
dt = 1 / freq
n_sample = 50 # help="number of trajectories", type=int, default=100
noise_ratio = 0.00 # help="noise level (default 0)", type=float, default=0.
dim_x = 3 # help="dimentionality of the problem", type=int
dim_k = 0 # help="dimentionality of the parameterizaiton discovery", type=int
# ode_param, freq = set_param_freq(ode_param, freq)
# ode = equations.get_ode(ode_name, ode_param)
# time_vector = np.arange(0, ode.T + dt, dt)

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, 0, freq, n_sample, noise_ratio, 'tv', 100, 1))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_SRT(ode_name, param, 0, freq, n_sample, noise_ratio, 'tv', seed=100, n_seed=1, T0=23, T=43)
None
# Out:
# Running with: ode_name=TVVdpODE, ode_param=5.0,5.0,1, x_id=0, freq=20, n_sample=50, noise_sigma=0.0, alg=tv, seed=100, n_seed=1
# Dataset shape:  (401, 50, 3)
# Functions set:  {'neg': 1, 'mul': 2, 'add': 1, 'sub': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    15.05      1.37363e+12        6          3.42708          3.61171      7.25m
#
# promising programs:
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(X1, X0), neg(X1))
# mul(neg(X1), mul(X0, X1))
# mul(mul(X1, neg(X1)), X0)
# mul(mul(X1, neg(X1)), X0)
# mul(mul(X1, neg(X1)), X0)
# mul(neg(X0), mul(X1, X1))
# mul(mul(X1, X0), neg(X1))
# mul(neg(X0), mul(X1, X1))
# mul(neg(X1), mul(X1, X0))
# mul(neg(X1), mul(X1, X0))
# mul(mul(X1, neg(X1)), X0)
# mul(neg(X0), mul(X1, X1))
# neg(mul(mul(X1, X1), X0))
# mul(mul(X1, neg(X1)), X0)
#
#    1     3.07          964.259       10          3.10886          3.12567      4.78m
#
# promising programs:
# mul(mul(neg(X1), mul(X0, X1)), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(neg(X1), mul(X0, X1)), mul(X1, X1))
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(neg(neg(2.184)), neg(mul(X1, X1))), X0)
# mul(mul(X1, neg(X1)), X0)
# mul(neg(X0), mul(X1, X1))
# neg(mul(mul(X1, X1), X0))
# neg(mul(mul(X1, X1), X0))
# mul(neg(X0), mul(X1, X1))
#
#    2     2.68          22754.3       10          3.00969          3.14907      4.65m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(neg(mul(2.760, X1)), mul(X1, X0))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(neg(X1), mul(X0, X1)), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(mul(mul(X1, neg(X1)), X0), mul(X1, X1))
# mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1))
# mul(mul(neg(X1), mul(X0, X1)), mul(X1, X1))
# mul(mul(neg(X0), mul(X1, X1)), mul(X1, X1))
# mul(mul(mul(X0, X1), neg(X1)), mul(X1, X1))
# mul(mul(mul(X1, X0), neg(X1)), mul(X1, X1))
# mul(mul(neg(X0), mul(X1, X1)), mul(X1, X1))
#
#    3     4.08           345950        8          2.64647          2.55868      3.80m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(mul(X1, X1)), mul(3.899, X0))
# mul(cos(mul(X1, X1)), mul(3.899, X0))
# mul(cos(mul(X1, neg(X1))), mul(3.899, X0))
# mul(neg(mul(2.760, X1)), mul(X1, X0))
# mul(neg(mul(2.760, X1)), mul(X0, X1))
# mul(neg(mul(2.760, X1)), mul(X1, X0))
# mul(neg(mul(2.760, X1)), mul(X1, X0))
# mul(neg(mul(2.760, X1)), mul(X1, X0))
# mul(mul(X1, neg(mul(2.760, X1))), X0)
# mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1))
# mul(mul(neg(X0), 2.272), mul(X1, X1))
#
#    4     6.31      6.10976e+08        8          2.63731          2.64114      4.66m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(mul(X1, X1)), mul(3.899, X0))
# mul(cos(mul(X1, X1)), mul(3.899, X0))
# mul(cos(mul(X1, X1)), mul(3.899, X0))
#
#    5     8.06           3826.7        8          2.37018          2.41964      3.54m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
#
#    6     9.52          1625.59        8          2.37244          2.39937      3.79m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
# mul(cos(add(X1, X1)), mul(3.899, X0))
#
#    7     9.47      1.89192e+08        8           2.3635          2.47979      3.26m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
#
#    8     8.67          58793.2        8           2.3631          2.48338      3.34m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
#
#    9     8.17      2.21121e+08       10          2.32579          2.35316      3.92m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
#
#   10     8.04           620645       10          2.32453          2.36452      3.19m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
#
#   11     8.01           156032       10          2.32131           2.3935      2.64m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
#
#   12     8.00          523.687        8          2.35014           2.5061      2.50m
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.974, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
#
#   13     8.06          554.459        8          2.34935          2.30964      2.01m
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.974, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
#
#   14     8.02          110.515        8          2.33802           2.4116      1.64m
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(add(X1, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
#
#   15     8.06          13233.9       10          2.27237          2.28678      1.49m
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
#
#   16     8.04          1773.89        8           2.3226          2.45272     58.58s
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.940, X0))
#
#   17     8.00          8995.68       13          2.09227          2.11462     42.14s
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
#
#   18     8.06      3.10855e+06       13          2.08255          2.20214     21.80s
#
# promising programs:
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.990, X0))
# mul(cos(mul(1.891, X1)), mul(4.974, X0))
#
#   19     8.07          1409.41       13          2.09065          2.12925      0.00s
#
# SR-T model:  (C*X0 + X1)*cos(C*X1)
#
# building blocks:
# cos(2*X1)
# cos(X1**2)
# cos(1.8905836435707468*X1)
# 5.392708120630252*X0 + X1
#
# number of building blocks:  4

# %%
print("Running with: ode_name={}, ode_param={}, x_id={}, freq={}, n_sample={}, noise_sigma={}, alg={}, seed={}, n_seed={}".format(
    ode_name, ode_param, 0, freq, n_sample, noise_ratio, 'tv', 100, 1))

if ode_param is not None:
    param = [float(x) for x in ode_param.split(',')]
else:
    param = None
if freq >= 1:
    freq = int(freq)
else:
    freq = freq

run_DCODE(ode_name, param, 0, freq, n_sample, noise_ratio=0.01, seed=100, n_seed=1, T0=20, T=40)
None
# Out:
# Running with: ode_name=TVVdpODE, ode_param=5.0,5.0,0.2, x_id=0, freq=20, n_sample=50, noise_sigma=0.0, alg=tv, seed=100, n_seed=1
# Data generated
# Dataset shape before smoothing:  (401, 50, 3)
# Dataset shape:  (401, 50, 3)
# Functions set:  {'neg': 1, 'mul': 2, 'add': 1, 'sub': 1, 'cos': 1}
#
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    15.05      1.79415e+32       27          6599.12          6791.89     11.54m
#    1     9.51       8.6153e+31       22          6532.17          6976.31      8.78m
#    2     6.31      3.23156e+16       19          5047.04          5171.72      6.26m
#
# promising programs:
# mul(cos(add(X1, X1)), mul(3.899, X0))
# add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1))
# add(sub(add(mul(mul(X0, X0), sub(X2, X2)), mul(sub(X0, X1), sub(X1, X1))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0)))), add(sub(X0, X1), mul(mul(X1, X0), neg(X1))))
# mul(cos(mul(neg(1.252), neg(X1))), sub(cos(sub(X0, X2)), mul(mul(X0, X1), add(mul(neg(mul(X0, X1)), X1), neg(X1)))))
# sub(add(mul(mul(X1, X1), neg(X0)), neg(X1)), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(neg(X1), mul(neg(X0), mul(X1, X1))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# add(add(mul(add(X0, X0), cos(neg(X1))), mul(neg(cos(X0)), add(mul(4.354, X0), cos(X2)))), neg(X1))
# sub(add(mul(mul(X1, X0), neg(X1)), cos(4.395)), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(mul(X0, X0), sub(X2, X2)), mul(neg(X1), mul(X1, X0))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(mul(neg(mul(X0, X1)), X1), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(mul(mul(X1, neg(X1)), X0), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(neg(mul(mul(X1, X0), X1)), mul(add(0.517, X0), sub(X1, X1))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(neg(X1), mul(X1, X0)), mul(sub(cos(X1), X1), sub(X1, X1))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(mul(neg(X1), neg(cos(add(cos(X1), cos(X0))))), sub(X2, X2)), mul(neg(X0), mul(X1, X1))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(neg(mul(mul(X1, X1), X0)), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
#
#    3    12.83      7.18237e+17        8           3405.2          3314.28      7.16m
#    4    24.18      8.94946e+25       23          1808.87          1789.95      9.21m
#
# promising programs:
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(mul(X0, cos(X1)), sub(X2, X2)), add(mul(mul(cos(add(neg(X1), neg(X1))), X0), mul(X1, X1)), neg(X1))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0))))))
# add(cos(mul(X0, cos(sub(mul(neg(mul(X0, X1)), cos(1.596)), neg(mul(neg(mul(X0, X1)), X1)))))), add(sub(sub(neg(X1), neg(mul(neg(mul(X0, X1)), X1))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0)))), mul(mul(X1, X0), neg(X1))))
# sub(add(sub(mul(cos(X1), X0), X0), add(mul(mul(X0, X0), sub(X2, X2)), mul(cos(add(X1, X1)), mul(3.899, X0)))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(mul(X0, X0), sub(X2, X2)), add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(cos(4.845), mul(cos(X1), X0)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(mul(X0, X0), sub(X2, X2)), add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(cos(4.845), mul(cos(X1), X0)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(mul(X0, X0), sub(X2, X2)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1))), mul(cos(mul(neg(X1), neg(2.408))), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(X1), add(X0, X0)), neg(mul(neg(mul(X0, X1)), X1)))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(neg(X1), mul(cos(add(X1, X1)), mul(3.899, X0))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(neg(mul(X0, X1)), X1), sub(add(cos(sub(mul(mul(sub(neg(1.037), cos(X1)), mul(mul(X1, X1), neg(X0))), cos(add(X0, X0))), mul(cos(neg(X0)), mul(add(X2, X2), cos(1.505))))), neg(X1)), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0))))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))
# add(add(mul(add(X0, X0), cos(X1)), mul(mul(mul(X0, X1), neg(X1)), mul(X1, X1))), neg(X1))
# mul(cos(mul(neg(1.252), neg(X1))), sub(cos(sub(X0, X2)), mul(mul(X0, X1), mul(mul(X1, X0), neg(X0)))))
# neg(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(X0, cos(X1)), sub(X2, X2)), mul(sub(X0, X1), sub(X1, X1))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0))))))
# sub(add(mul(mul(cos(sub(X0, X1)), neg(cos(add(cos(X1), cos(X0))))), sub(X2, X2)), sub(mul(mul(X1, X1), neg(X0)), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0))))), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0))))
# sub(sub(neg(mul(mul(X1, X1), X0)), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0)))), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0))))
# sub(add(mul(neg(X1), mul(X1, X0)), neg(X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0))))
#
#    5    27.67      5.32279e+13       47          679.194          664.875      9.22m
#    6    30.91      1.23454e+13       35          303.798          286.716      9.21m
#    7    38.55      5.71356e+12       40           228.26          252.891      8.03m
#    8    45.71      1.53827e+16       40          228.954           246.64      8.57m
#    9    48.82      6.78932e+12       46          140.771          131.725      7.83m
#
# promising programs:
# neg(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(X0, cos(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))
# neg(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(cos(0.057), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))
# neg(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(X0, cos(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))
# neg(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(X0, cos(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(cos(X1), X0), sub(X2, X2))), neg(X0))))))
# sub(add(neg(X1), add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), X0)), mul(cos(mul(X1, neg(X1))), mul(3.176, neg(X0))))
# neg(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(sub(X0, X1), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))
# sub(add(neg(X0), add(sub(X0, X1), sub(add(mul(neg(X0), mul(2.351, mul(X1, X1))), mul(X0, cos(sub(mul(neg(cos(1.596)), cos(1.596)), neg(add(X1, X1)))))), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0)))))), mul(cos(1.252), mul(sub(3.176, X1), neg(X0))))
# sub(add(neg(X0), add(sub(X0, X1), sub(add(mul(neg(X0), mul(2.351, mul(X1, X1))), mul(X0, cos(sub(mul(neg(cos(1.596)), cos(1.596)), neg(add(X1, X1)))))), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0)))))), mul(cos(1.252), mul(sub(3.176, X1), neg(X0))))
# sub(add(neg(X0), add(sub(X0, X1), sub(add(mul(neg(X0), mul(2.351, mul(X1, X1))), mul(X0, cos(sub(mul(neg(cos(1.596)), cos(mul(X1, neg(X1)))), neg(add(X1, X1)))))), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0)))))), mul(cos(1.252), mul(sub(3.176, X1), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(cos(neg(mul(0.398, neg(mul(X1, X0))))))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, X1), neg(X0))))
# add(mul(cos(X1), X0), add(sub(sub(neg(X1), neg(mul(neg(mul(X1, X0)), X1))), mul(cos(mul(X1, add(mul(mul(cos(add(X2, neg(X1))), X0), sub(X1, X1)), neg(X1)))), mul(3.176, neg(X0)))), mul(mul(X1, X0), neg(X1))))
# add(mul(cos(X1), X0), add(sub(sub(neg(X1), neg(mul(neg(mul(X1, X0)), X1))), mul(cos(mul(X1, neg(X1))), mul(3.176, neg(X0)))), mul(mul(X1, X0), neg(X1))))
# add(mul(cos(X1), X0), add(sub(sub(neg(X1), neg(mul(neg(mul(X1, X0)), X1))), mul(cos(mul(X1, neg(X1))), mul(3.176, neg(X0)))), mul(mul(X1, X0), neg(X1))))
# mul(add(mul(neg(X0), mul(X1, X1)), add(neg(add(mul(cos(X1), neg(add(X0, mul(X0, mul(mul(X1, X1), mul(X1, X1)))))), X1)), sub(add(mul(neg(X0), mul(X1, X1)), mul(sub(X0, X1), sub(X1, X1))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0)))))), cos(mul(mul(mul(X2, X0), sub(X1, X1)), mul(mul(X2, X1), add(X2, X1)))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(add(add(mul(cos(1.505), cos(X1)), mul(mul(X1, neg(X1)), X0)), mul(cos(X1), X0)), add(mul(mul(cos(add(neg(X1), neg(X1))), X0), sub(X1, X1)), neg(X1))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, add(X1, neg(X1))), neg(X0))))))
#
#   10    51.64      1.13449e+19       46          138.656          150.766      7.35m
#   11    53.16      8.64627e+16       55          64.7096          54.0456      6.02m
#   12    52.29      6.02179e+11       55          62.5051          73.8865      5.60m
#   13    53.73      2.25297e+14       64          62.4614          69.5667      4.86m
#   14    56.27      1.31395e+11       34          58.1211          69.6376      4.27m
#
# promising programs:
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(add(mul(neg(X0), sub(X2, X2)), add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(X0, neg(X1)))), mul(cos(mul(X1, neg(X1))), mul(3.176, neg(X0)))), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(neg(cos(2.481)), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, mul(cos(neg(X0)), cos(cos(mul(X1, X1))))), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(add(X2, neg(X0)))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, mul(cos(neg(X0)), mul(0.180, X1))), neg(X0))))
# sub(add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(neg(X1), mul(cos(X1), X0))), mul(cos(mul(X1, mul(X1, X1))), mul(sub(3.176, mul(X1, X1)), neg(X0))))
# sub(add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(neg(X1), mul(cos(X1), X0))), mul(cos(mul(X1, mul(X1, X1))), mul(sub(3.176, mul(X1, X1)), neg(X0))))
# sub(add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(neg(X1), mul(cos(X1), X0))), mul(cos(mul(X1, mul(X1, X1))), mul(sub(3.176, mul(X1, X1)), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(mul(X1, 3.803))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, sub(X1, X1)), neg(X0))))
# sub(add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(neg(X1), mul(cos(X1), X0))), mul(cos(mul(X1, mul(X1, X1))), mul(sub(3.176, mul(X1, X1)), neg(X0))))
# sub(add(mul(neg(mul(mul(cos(0.057), mul(X1, X1)), X0)), mul(X1, X1)), add(neg(X1), mul(cos(X1), X0))), mul(cos(mul(X1, mul(X1, X1))), mul(sub(3.176, mul(X1, X1)), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1))), neg(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, sub(X1, X1)), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(X1, neg(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, sub(X1, X1)), neg(X0))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(sub(X2, X2), add(mul(mul(cos(add(neg(X1), neg(X1))), X0), mul(X1, X1)), sub(sub(mul(X0, cos(X1)), sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(sub(X1, X1), mul(cos(add(X1, X1)), mul(cos(X1), neg(X0)))))), X1))), mul(cos(neg(X1)), mul(sub(3.176, sub(X2, X2)), neg(X0))))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(sub(add(mul(neg(add(neg(X0), cos(3.125))), X1), sub(add(cos(sub(mul(X1, X1), mul(cos(mul(X1, sub(X2, X2))), mul(3.176, neg(X0))))), neg(X1)), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, X1), neg(X0))))), mul(cos(mul(X1, X0)), mul(sub(3.176, X1), neg(X0)))), cos(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(mul(X0, X0), sub(X2, X2))), neg(X0))))))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, sub(X1, X1)), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(add(X2, neg(mul(sub(X0, X1), neg(cos(2.481))))))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, mul(cos(neg(X0)), mul(0.180, X1))), neg(X0))))
# sub(add(add(mul(neg(X1), mul(X1, X0)), sub(mul(cos(cos(sub(mul(X0, mul(mul(X1, X1), mul(X1, X1))), sub(add(mul(mul(X1, neg(X1)), sub(X2, X2)), mul(sub(X0, X1), neg(cos(2.481)))), mul(cos(mul(X1, neg(X1))), mul(sub(3.176, mul(add(mul(cos(add(neg(X1), neg(X1))), X0), neg(X1)), sub(X2, X2))), neg(X0))))))), add(X0, X0)), neg(mul(neg(X0), mul(X1, X1))))), sub(mul(mul(X1, X1), neg(X0)), X1)), mul(cos(mul(X1, X1)), mul(sub(3.176, sub(X1, X1)), neg(X0))))
#
#   15    60.86      2.43458e+13       80          31.9989          30.8841      3.77m
#   16    71.63      6.33512e+12       72          29.8863          49.8978      3.23m
#   17    70.79      5.11819e+15      126          29.7752          50.8979      2.50m
#   18    72.99      4.89253e+20       68          28.0803          66.1516      1.21m
#
# promising programs:
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(mul(cos(mul(X1, neg(X1))), mul(3.176, neg(X0))), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(add(X1, neg(X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(sub(3.176, add(X1, neg(X1))), neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(mul(X0, cos(X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(sub(3.176, add(X1, neg(X1))), neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(add(mul(neg(X0), sub(X2, X2)), add(mul(neg(mul(mul(X1, X1), X0)), mul(mul(X1, X1), X0)), add(X0, mul(X1, X1)))), mul(cos(mul(X1, neg(X1))), neg(add(neg(X0), cos(3.125))))), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(add(mul(mul(X0, X2), sub(1.880, X0)), mul(mul(sub(X0, X1), cos(X1)), sub(X2, X2))), neg(X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(add(mul(neg(X0), sub(X2, X2)), mul(X0, mul(cos(0.057), mul(X1, X1)))), mul(cos(mul(X1, neg(X1))), X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(neg(X0), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(mul(mul(X1, X1), sub(X2, X2)), mul(cos(mul(X1, neg(X1))), neg(add(neg(X0), cos(neg(X2)))))), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(add(mul(sub(3.176, add(X1, neg(X1))), neg(X0)), add(mul(neg(mul(mul(X1, X1), X0)), mul(X1, X1)), add(X0, neg(X1)))), cos(cos(X1))), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(add(X1, neg(X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(sub(3.176, add(X1, neg(X1))), neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(mul(X1, neg(X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(sub(3.176, add(X1, neg(X1))), neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(neg(X1), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(sub(X1, X1), mul(cos(mul(X1, neg(X1))), X1)), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(add(X0, X0), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
# neg(sub(mul(X0, mul(cos(0.057), mul(X1, X1))), sub(add(mul(sub(add(mul(neg(X0), sub(X2, X2)), add(mul(cos(neg(X1)), mul(3.176, neg(X0))), add(X0, neg(X1)))), mul(cos(mul(X1, neg(X1))), neg(add(cos(X0), cos(3.125))))), sub(X2, X2)), add(mul(neg(X0), mul(X1, X1)), add(add(mul(add(X0, X0), cos(X1)), mul(neg(X0), mul(X1, X1))), neg(X1)))), mul(cos(neg(X1)), mul(3.176, neg(X0))))))
#
#   19    77.65      1.24126e+14       85          27.9381          67.4312      0.00s
#
# D-CODE model:  -C*X0*X1**C + C*X0*cos(X1) - X1
#
# building blocks:
# cos(2*X1)
# cos(X1)
# cos(X0*X1)
# cos(X0)
# cos(X1**2)
# cos(2.4084327652450583*X1)
# cos(cos(X1**2))
# cos(cos(X0 - X2))
# cos(X1**3)
# cos(X2)
# -X1
# 5.17605043127894*X0*cos(X1)
# -2.99835303576384*X0*X1**2
#
# number of building blocks:  13

# %% [markdown]
# #### Computation std

# %%
# generate data:
X_list, dX_list, param_list, feature_names = SINDy_data.SINDy_data(ode_name=ode_name, 
                                                                   ode_param=ode_param,
                                                                   freq=freq,
                                                                   n_sample=200,
                                                                   noise_ratio=0.0,
                                                                   dim_x=dim_x,
                                                                   dim_k=dim_k)

X = np.array(dX_list)[:,:,:]
print('Shape: ',X.shape)

vec_rmse = []
for i in range(X.shape[0]):
    rmse = root_mean_squared_error(X[i], np.zeros(X[i].shape))
    print('RMSE: ', rmse)
    vec_rmse.append(rmse)

vec_rmse = np.array(vec_rmse)
print('RMSE Mean: ', vec_rmse.mean())
# Out:
# Shape:  (200, 3000, 3)
# RMSE:  5.279721660039329
# RMSE:  5.270095660861505
# RMSE:  5.273986653326706
# RMSE:  5.264315906433606
# RMSE:  5.28188342149018
# RMSE:  5.251666815085244
# RMSE:  5.267562439896801
# RMSE:  5.283543087572263
# RMSE:  5.2804055237755945
# RMSE:  5.267184432796553
# RMSE:  5.262135304731353
# RMSE:  5.275117742082892
# RMSE:  5.273536239582056
# RMSE:  5.274998041325863
# RMSE:  5.272013301512658
# RMSE:  5.283879156688033
# RMSE:  5.267614450708
# RMSE:  5.2868130275506795
# RMSE:  5.263747155694158
# RMSE:  5.2603350208057105
# RMSE:  5.280459256499874
# RMSE:  5.2720929098449085
# RMSE:  5.279125717944047
# RMSE:  5.270111299947378
# RMSE:  5.252520233273891
# RMSE:  5.276146103601316
# RMSE:  5.250016147473141
# RMSE:  5.272727782122682
# RMSE:  5.273232439703711
# RMSE:  5.263446762502803
# RMSE:  5.272888150004416
# RMSE:  5.2699336973799005
# RMSE:  5.262367808916417
# RMSE:  5.274436123039607
# RMSE:  5.2794328768301275
# RMSE:  5.275761489089079
# RMSE:  5.274503331126103
# RMSE:  5.276437838042773
# RMSE:  5.27034389724186
# RMSE:  5.259535484912388
# RMSE:  5.270187814043171
# RMSE:  5.257434821870768
# RMSE:  5.283102989516139
# RMSE:  5.271993130103055
# RMSE:  5.269671358224139
# RMSE:  5.2698400525260425
# RMSE:  5.26792390081878
# RMSE:  5.253326112465529
# RMSE:  5.2738137202670305
# RMSE:  5.285224992141592
# RMSE:  5.2709377499383105
# RMSE:  5.268480934004173
# RMSE:  5.2628376895545435
# RMSE:  5.261752471925462
# RMSE:  5.259529895198102
# RMSE:  5.278123114179336
# RMSE:  5.27177203953264
# RMSE:  5.249455877789528
# RMSE:  5.270234895104113
# RMSE:  5.254351551452695
# RMSE:  5.267946516594981
# RMSE:  5.27167459494689
# RMSE:  5.281860215093813
# RMSE:  5.267560832385836
# RMSE:  5.283533023030027
# RMSE:  5.269778750680247
# RMSE:  5.281742941818371
# RMSE:  5.266634157362328
# RMSE:  5.2570895100565105
# RMSE:  5.2689772588114385
# RMSE:  5.281515059405417
# RMSE:  5.263270713429485
# RMSE:  5.257863938028488
# RMSE:  5.245349416482713
# RMSE:  5.266346925255214
# RMSE:  5.2784590390431605
# RMSE:  5.252487854117469
# RMSE:  5.266786031732533
# RMSE:  5.269590115267171
# RMSE:  5.273177780982354
# RMSE:  5.268021830578664
# RMSE:  5.270979889011687
# RMSE:  5.253784204304903
# RMSE:  5.283680818379253
# RMSE:  5.2688667792057595
# RMSE:  5.271536994600547
# RMSE:  5.276638675703489
# RMSE:  5.2683527766166796
# RMSE:  5.2826814590494005
# RMSE:  5.271967173789649
# RMSE:  5.262025150314126
# RMSE:  5.261800223410382
# RMSE:  5.284782917723266
# RMSE:  5.278202850460252
# RMSE:  5.269662849084463
# RMSE:  5.269183842306819
# RMSE:  5.270783949276864
# RMSE:  5.270550207511126
# RMSE:  5.271266898787513
# RMSE:  5.279346626550263
# RMSE:  5.251018562693196
# RMSE:  5.2572218580477434
# RMSE:  5.268481321140451
# RMSE:  5.282960112299134
# RMSE:  5.269747269524539
# RMSE:  5.270963417635921
# RMSE:  5.259064916249451
# RMSE:  5.256677393440419
# RMSE:  5.2717026560707385
# RMSE:  5.270812627189681
# RMSE:  5.270958481743951
# RMSE:  5.269340487305239
# RMSE:  5.272285293272683
# RMSE:  5.267138005514224
# RMSE:  5.248196283782619
# RMSE:  5.275285834156714
# RMSE:  5.266138979868169
# RMSE:  5.280469955442224
# RMSE:  5.2694112912172875
# RMSE:  5.267613675366861
# RMSE:  5.267166230843237
# RMSE:  5.264731782746708
# RMSE:  5.271445448850392
# RMSE:  5.282840710982286
# RMSE:  5.2660702831926605
# RMSE:  5.258161090632768
# RMSE:  5.271494559472207
# RMSE:  5.275751470582324
# RMSE:  5.271286122272283
# RMSE:  5.278082047074386
# RMSE:  5.274100914753615
# RMSE:  5.278621508211137
# RMSE:  5.285059077912479
# RMSE:  5.285523268801467
# RMSE:  5.247239236566979
# RMSE:  5.268189698422234
# RMSE:  5.271446646130847
# RMSE:  5.26912032358712
# RMSE:  5.2653652123601065
# RMSE:  5.280452930164281
# RMSE:  5.262597090769177
# RMSE:  5.274242529299424
# RMSE:  5.269814346236356
# RMSE:  5.280083873805501
# RMSE:  5.273561680555026
# RMSE:  5.262290649145952
# RMSE:  5.274703959656329
# RMSE:  5.285762579551416
# RMSE:  5.264746318073422
# RMSE:  5.251258244034186
# RMSE:  5.271650366300533
# RMSE:  5.249730402329123
# RMSE:  5.283063275408673
# RMSE:  5.26753874765851
# RMSE:  5.270846981793418
# RMSE:  5.252527657166927
# RMSE:  5.262133397070012
# RMSE:  5.282661136488412
# RMSE:  5.276870924123101
# RMSE:  5.285528892539767
# RMSE:  5.27950300825799
# RMSE:  5.26630170847942
# RMSE:  5.28276389708149
# RMSE:  5.262458257592947
# RMSE:  5.253353358917575
# RMSE:  5.258876253633039
# RMSE:  5.251161424627408
# RMSE:  5.27025506348138
# RMSE:  5.271089181292452
# RMSE:  5.282464782883841
# RMSE:  5.261472255983175
# RMSE:  5.26943415477693
# RMSE:  5.249327293398701
# RMSE:  5.269514826795877
# RMSE:  5.266382181273005
# RMSE:  5.272476226472857
# RMSE:  5.272207797850183
# RMSE:  5.26439455738331
# RMSE:  5.263049984609942
# RMSE:  5.270271641893735
# RMSE:  5.276890167595815
# RMSE:  5.275209249126707
# RMSE:  5.282846028933865
# RMSE:  5.271651877134185
# RMSE:  5.2447926929803215
# RMSE:  5.273081244595663
# RMSE:  5.273016903028911
# RMSE:  5.262176666192109
# RMSE:  5.27016256631828
# RMSE:  5.273052660199923
# RMSE:  5.270077083965538
# RMSE:  5.271542472011023
# RMSE:  5.2653633049013235
# RMSE:  5.272575450915477
# RMSE:  5.264072947086947
# RMSE:  5.273604943045707
# RMSE:  5.285817007842591
# RMSE:  5.274608916025474
# RMSE:  5.269986023080454
# RMSE:  5.277728186477516
# RMSE Mean:  5.269730472894847
